# %%
arr1=np.array([1,2,3,4,5])
arr2=np.array([2,5,4,1,7])
a=np.zeros((3,3),int)
a=3+arr1 #broadcasting
a=arr1+arr2 #elementary operations
print(a)
# Out:
# [4 5 6 7 8]

# %%
import numpy as np
arr=np.array([1,2,3,4,5])
print(arr)
a=np.zeros((3,3))
print(a)
b=np.ones((3,3))
print(b)
c=np.arange(10)
print(c)
#manuplations
arr_reshaped=arr.reshape(5,1)
print(arr_reshaped)
arr_sliced=arr[2:4]
print(arr_sliced)

# %%
arr1=np.array([1,2,3,4,5])
arr2=np.array([2,5,4,1,7])
b=np.vstack(arr1+arr2) #adding verically
print(b)
# Out:
# [[ 3]
#  [ 7]
#  [ 7]
#  [ 5]
#  [12]]

# %%
arr1=np.array([1,2,3,4,5])
arr2=np.array([2,5,4,1,7])
b=np.stack(arr1+arr2) #adding and adding verically
print(b)
# Out:
# [ 3  7  7  5 12]

# %%
arr1=np.array([1,2,3,4,5,6])
arr2=np.split(arr1,3)
print(arr2)
# Out:
# [array([1, 2]), array([3, 4]), array([5, 6])]

# %%
arr1=np.array([[1,2,3],[4,5,6]])
arr2=arr1.T
print(arr2)
# Out:
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
#linear algebra using numpy
arr1=np.array([[1,2],[5,6]])
arr2=np.array([[2,3],[4,5]])
arr3=np.dot(arr1,arr2)
d=np.linalg.eig(arr3)
print(d)
# Out:
# (array([ 0.14584127, 54.85415873]), array([[-0.7969247 , -0.27837224],
#        [ 0.60407865, -0.96047327]]))

# %%
import numpy as np
arr1=np.array([[1,2,9],[5,6,7]])
arr2=np.array([[1,2,9],[5,6,7]])
arr3=np.sum(arr1,axis=0)#column wise
print(arr3)
arr4=np.sum(arr1,axis=1)#row wise
print(arr4)
# Out:
# [ 6  8 16]
# [12 18]

# %%
#statistical
arr1=np.array([1,2,9,5,6,7])
arr2=np.array([[1,2,9],[5,6,7]])
print("mean",np.mean(arr1))
print("median",np.median(arr1))
print("variance",np.var(arr1))
print("standard deviation",np.std(arr1))
# Out:
# mean 5.0
# median 5.5
# variance 7.666666666666667
# standard deviation 2.7688746209726918

# %%
import matplotlib.pyplot as plt
data=np.loadtxt("/content/ppp.txt",dtype=int)
plt.plot(data)
d=np.savetxt("/content/mmm.txt",data)
print(d)
# Out:
# <ipython-input-45-993ae36ed5bd>:2: DeprecationWarning: loadtxt(): Parsing an integer via a float is deprecated.  To avoid this warning, you can:
#     * make sure the original data is stored as integers.
#     * use the `converters=` keyword argument.  If you only use
#       NumPy 1.23 or later, `converters=float` will normally work.
#     * Use `np.loadtxt(...).astype(np.int64)` parsing the file as
#       floating point and then convert it.  (On all NumPy versions.)
#   (Deprecated NumPy 1.23)
#   data=np.loadtxt("/content/ppp.txt",dtype=int)
# [<matplotlib.lines.Line2D at 0x794ab90ab040>,
#  <matplotlib.lines.Line2D at 0x794ab90ab2b0>,
#  <matplotlib.lines.Line2D at 0x794ab90ab250>,
#  <matplotlib.lines.Line2D at 0x794ab90aae60>,
#  <matplotlib.lines.Line2D at 0x794ab90ab6d0>,
#  <matplotlib.lines.Line2D at 0x794ab90aa680>,
#  <matplotlib.lines.Line2D at 0x794ab90ab9a0>,
#  <matplotlib.lines.Line2D at 0x794ab90abdc0>]

# %%
import matplotlib.pyplot as plt
a=np.array([1,2,3,4,5])
plt.plot(a)

# %%
import pandas as pd
a=["jwalitha","ramya","durga","jahnavi","lahari","sunny","dhanush"]
r=pd.Series(a,index=[67,43,44,89,34,45,23])
print(r)
# Out:
# 67    jwalitha
# 43       ramya
# 44       durga
# 89     jahnavi
# 34      lahari
# 45       sunny
# 23     dhanush
# dtype: object

# %% [markdown]
# df=pd.read_csv("/content/Consumer_Complaints.csv")
# df.shape

# %%
df=pd.read_csv("",sep=" ")
print(df)
# Out:
#                                                            CourseID  \
# CSE101 Introduction   to           Computer    Science          Dr.
# CSE102 Data           Structures   Dr.         Bob            Jones
# CSE103 Algorithms     Dr.          Charlie     Davis             88
# CSE104 Computer       Organization Dr.         Diane          Clark
# CSE105 Operating      Systems      Dr.         Evan          Wright
# CSE201 Database       Systems      Dr.         Fiona           Chen
# CSE202 Computer       Networks     Dr.         George           Lee
# CSE203 Software       Engineering  Dr.         Hannah        Martin
# CSE204 Web            Development  Dr.         Ian         Thompson
# CSE205 Artificial     Intelligence Dr.         Julia            Kim
# CSE206 Machine        Learning     Dr.         Kyle           Patel
# CSE207 Cybersecurity  Dr.          Laura       White             78
# CSE208 Cloud          Computing    Dr.         Mike           Brown
# CSE209 Mobile         App          Development Dr.            Nancy
# CSE210 Game           Development  Dr.         Oliver         Scott
# CSE301 Internet       of           Things      Dr.         Patricia
# CSE302 Big            Data         Analytics   Dr.          Quentin
# CSE303 Blockchain     Technology   Dr.         Rachel         Green
# CSE304 Virtual        Reality      Dr.         Steve         Murphy
# CSE305 Augmented      Reality      Dr.         Tara          Wilson
# CSE306 Quantum        Computing    Dr.         Uma             Iyer
# CSE307 Human-Computer Interaction  Dr.         Victor        Torres
# CSE308 Robotics       Dr.          Wendy       Hill              83
# CSE309 Bioinformatics Dr.          Xavier      Gonzalez          70
# CSE310 Computational  Finance      Dr.         Yolanda      Vasquez
# CSE311 Digital        Image        Processing  Dr.          Zachary
# CSE312 Natural        Language     Processing  Dr.           Amelia
# CSE313 Computer       Graphics     Dr.         Neil       Armstrong
# CSE314 Parallel       Computing    Dr.         Margaret    Hamilton
# CSE315 Information    Retrieval    Dr.         Katherine    Johnson
#
#                                                          CourseName  \
# CSE101 Introduction   to           Computer    Science        Alice
# CSE102 Data           Structures   Dr.         Bob               95
# CSE103 Algorithms     Dr.          Charlie     Davis            NaN
# CSE104 Computer       Organization Dr.         Diane             76
# CSE105 Operating      Systems      Dr.         Evan              89
# CSE201 Database       Systems      Dr.         Fiona             92
# CSE202 Computer       Networks     Dr.         George            85
# CSE203 Software       Engineering  Dr.         Hannah           105
# CSE204 Web            Development  Dr.         Ian               98
# CSE205 Artificial     Intelligence Dr.         Julia            110
# CSE206 Machine        Learning     Dr.         Kyle             115
# CSE207 Cybersecurity  Dr.          Laura       White            NaN
# CSE208 Cloud          Computing    Dr.         Mike              82
# CSE209 Mobile         App          Development Dr.           Garcia
# CSE210 Game           Development  Dr.         Oliver            99
# CSE301 Internet       of           Things      Dr.        Rodriguez
# CSE302 Big            Data         Analytics   Dr.            Moore
# CSE303 Blockchain     Technology   Dr.         Rachel            73
# CSE304 Virtual        Reality      Dr.         Steve             69
# CSE305 Augmented      Reality      Dr.         Tara              74
# CSE306 Quantum        Computing    Dr.         Uma               65
# CSE307 Human-Computer Interaction  Dr.         Victor            79
# CSE308 Robotics       Dr.          Wendy       Hill             NaN
# CSE309 Bioinformatics Dr.          Xavier      Gonzalez         NaN
# CSE310 Computational  Finance      Dr.         Yolanda           75
# CSE311 Digital        Image        Processing  Dr.           Newman
# CSE312 Natural        Language     Processing  Dr.          Earhart
# CSE313 Computer       Graphics     Dr.         Neil              90
# CSE314 Parallel       Computing    Dr.         Margaret          77
# CSE315 Information    Retrieval    Dr.         Katherine         84
#
#                                                          Instructor  \
# CSE101 Introduction   to           Computer    Science        Smith
# CSE102 Data           Structures   Dr.         Bob              NaN
# CSE103 Algorithms     Dr.          Charlie     Davis            NaN
# CSE104 Computer       Organization Dr.         Diane            NaN
# CSE105 Operating      Systems      Dr.         Evan             NaN
# CSE201 Database       Systems      Dr.         Fiona            NaN
# CSE202 Computer       Networks     Dr.         George           NaN
# CSE203 Software       Engineering  Dr.         Hannah           NaN
# CSE204 Web            Development  Dr.         Ian              NaN
# CSE205 Artificial     Intelligence Dr.         Julia            NaN
# CSE206 Machine        Learning     Dr.         Kyle             NaN
# CSE207 Cybersecurity  Dr.          Laura       White            NaN
# CSE208 Cloud          Computing    Dr.         Mike             NaN
# CSE209 Mobile         App          Development Dr.               94
# CSE210 Game           Development  Dr.         Oliver           NaN
# CSE301 Internet       of           Things      Dr.               81
# CSE302 Big            Data         Analytics   Dr.               87
# CSE303 Blockchain     Technology   Dr.         Rachel           NaN
# CSE304 Virtual        Reality      Dr.         Steve            NaN
# CSE305 Augmented      Reality      Dr.         Tara             NaN
# CSE306 Quantum        Computing    Dr.         Uma              NaN
# CSE307 Human-Computer Interaction  Dr.         Victor           NaN
# CSE308 Robotics       Dr.          Wendy       Hill             NaN
# CSE309 Bioinformatics Dr.          Xavier      Gonzalez         NaN
# CSE310 Computational  Finance      Dr.         Yolanda          NaN
# CSE311 Digital        Image        Processing  Dr.               80
# CSE312 Natural        Language     Processing  Dr.               93
# CSE313 Computer       Graphics     Dr.         Neil             NaN
# CSE314 Parallel       Computing    Dr.         Margaret         NaN
# CSE315 Information    Retrieval    Dr.         Katherine        NaN
#
#                                                           Enrollment
# CSE101 Introduction   to           Computer    Science         120.0
# CSE102 Data           Structures   Dr.         Bob               NaN
# CSE103 Algorithms     Dr.          Charlie     Davis             NaN
# CSE104 Computer       Organization Dr.         Diane             NaN
# CSE105 Operating      Systems      Dr.         Evan              NaN
# CSE201 Database       Systems      Dr.         Fiona             NaN
# CSE202 Computer       Networks     Dr.         George            NaN
# CSE203 Software       Engineering  Dr.         Hannah            NaN
# CSE204 Web            Development  Dr.         Ian               NaN
# CSE205 Artificial     Intelligence Dr.         Julia             NaN
# CSE206 Machine        Learning     Dr.         Kyle              NaN
# CSE207 Cybersecurity  Dr.          Laura       White             NaN
# CSE208 Cloud          Computing    Dr.         Mike              NaN
# CSE209 Mobile         App          Development Dr.               NaN
# CSE210 Game           Development  Dr.         Oliver            NaN
# CSE301 Internet       of           Things      Dr.               NaN
# CSE302 Big            Data         Analytics   Dr.               NaN
# CSE303 Blockchain     Technology   Dr.         Rachel            NaN
# CSE304 Virtual        Reality      Dr.         Steve             NaN
# CSE305 Augmented      Reality      Dr.         Tara              NaN
# CSE306 Quantum        Computing    Dr.         Uma               NaN
# CSE307 Human-Computer Interaction  Dr.         Victor            NaN
# CSE308 Robotics       Dr.          Wendy       Hill              NaN
# CSE309 Bioinformatics Dr.          Xavier      Gonzalez          NaN
# CSE310 Computational  Finance      Dr.         Yolanda           NaN
# CSE311 Digital        Image        Processing  Dr.               NaN
# CSE312 Natural        Language     Processing  Dr.               NaN
# CSE313 Computer       Graphics     Dr.         Neil              NaN
# CSE314 Parallel       Computing    Dr.         Margaret          NaN
# CSE315 Information    Retrieval    Dr.         Katherine         NaN

# %%
# Out:
# (30, 7)

# %%
df=pd.read_csv("/content/black.txt",sep="  ")
print(df.loc[2:10])
# Out:
#    CourseID               CourseName         Instructor  Enrollment
# 2    CSE103               Algorithms  Dr. Charlie Davis        88.0
# 3    CSE104    Computer Organization    Dr. Diane Clark        76.0
# 4    CSE105        Operating Systems    Dr. Evan Wright        89.0
# 5    CSE201         Database Systems     Dr. Fiona Chen        92.0
# 6    CSE202        Computer Networks     Dr. George Lee        85.0
# 7    CSE203     Software Engineering  Dr. Hannah Martin       105.0
# 8    CSE204          Web Development   Dr. Ian Thompson        98.0
# 9    CSE205  Artificial Intelligence      Dr. Julia Kim       110.0
# 10   CSE206         Machine Learning     Dr. Kyle Patel       115.0
# <ipython-input-27-ea5dc33ea305>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv("/content/black.txt",sep="  ")

# %%
df=pd.read_excel("/content/spam.xlsx")
print(df)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
# 5572   ham                                        hi everyone        NaN
# 5573  spam                         you won a jackpot hurry up        NaN
# 5574  spam                          you won a jackpot hurryup        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5570        NaN        NaN
# 5571        NaN        NaN
# 5572        NaN        NaN
# 5573        NaN        NaN
# 5574        NaN        NaN
#
# [5575 rows x 5 columns]

# %%
df=pd.read_excel("/content/spammmmm.xlsx")
print(df)
# Out:
#         v1                                                 v2  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
# 5572   ham                                        hi everyone
# 5573  spam                         you won a jackpot hurry up
# 5574  spam                          you won a jackpot hurryup
#
#                                              Unnamed: 2  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                              Unnamed: 3  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                              Unnamed: 4  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                              Unnamed: 5  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                              Unnamed: 6  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                              Unnamed: 7  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                              Unnamed: 8  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                              Unnamed: 9  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                             Unnamed: 10  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                             Unnamed: 11  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                             Unnamed: 12  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                             Unnamed: 13  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                             Unnamed: 14  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                             Unnamed: 15  \
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
#                                             Unnamed: 16
# 0     Go until jurong point, crazy.. Available only ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5570                                                NaN
# 5571                                                NaN
# 5572                                                NaN
# 5573                                                NaN
# 5574                                                NaN
#
# [5575 rows x 17 columns]

# %%
dfn=pd.read_excel("/content/file_example_XLSX_100.xlsx")
mv=dfn['Age'].mean()
dfn=dfn.fillna(mv)
print(mv)
# Out:
# 33.26

# %%
dfn=dfn.drop_duplicates()
print(dfn)
# Out:
#       0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0     1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1     2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2     3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3     4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4     5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# ..  ...        ...         ...     ...            ...  ...         ...   ...
# 95   96       Roma  Lafollette  Female  United States   34  15/10/2017  2654
# 96   97     Felisa        Cail  Female  United States   28  16/08/2016  6525
# 97   98   Demetria       Abbey  Female  United States   32  21/05/2015  3265
# 98   99     Jeromy        Danz    Male  United States   39  15/10/2017  3265
# 99  100   Rasheeda      Alkire  Female  United States   29  16/08/2016  6125
#
# [100 rows x 8 columns]

# %%
mt=pd.read_csv("/content/manual_testing.csv",sep=",")
print(mt)
#print(mt.groupby(['']))
# Out:
#   Unnamed: 0  Unnamed: 1.1      Unnamed: 2 Unnamed: 3.1  Unnamed: 4 CourseID  \
# 0     CSE306           NaN         Quantum    Computing         NaN      Dr.
# 1     CSE307           NaN  Human-Computer  Interaction         NaN      Dr.
# 2     CSE308           NaN        Robotics          NaN         Dr.    Wendy
# 3     CSE309           NaN  Bioinformatics          NaN         Dr.   Xavier
# 4     CSE310           NaN   Computational      Finance         NaN      Dr.
# 5     CSE311           NaN         Digital        Image  Processing      NaN
# 6     CSE312           NaN         Natural     Language  Processing      NaN
# 7     CSE313           NaN        Computer     Graphics         NaN      Dr.
# 8     CSE314           NaN        Parallel    Computing         NaN      Dr.
# 9     CSE315           NaN     Information    Retrieval         NaN      Dr.
#
#   Unnamed: 1 CourseName Unnamed: 3  Instructor  Unnamed: 5  Enrollment
# 0        Uma       Iyer        NaN        65.0         NaN         NaN
# 1     Victor     Torres        NaN        79.0         NaN         NaN
# 2       Hill        NaN         83         NaN         NaN         NaN
# 3   Gonzalez        NaN         70         NaN         NaN         NaN
# 4    Yolanda    Vasquez        NaN        75.0         NaN         NaN
# 5        Dr.    Zachary     Newman         NaN        80.0         NaN
# 6        Dr.     Amelia    Earhart         NaN        93.0         NaN
# 7       Neil  Armstrong        NaN        90.0         NaN         NaN
# 8   Margaret   Hamilton        NaN        77.0         NaN         NaN
# 9  Katherine    Johnson        NaN        84.0         NaN         NaN

# %%
df=pd.read_csv("/content/food_prices_watch.csv")
a=df.head(10)
b=df.tail(10)
mt=pd.concat([a,b],axis=0)
d=mt.to_csv("man.csv")
#print(d.groupby(['ItemLabels'])['16-Jan'].count())
#d.groupby(['ItemLabels'])['16-Jan'].count().plot(kind="bar")
# Out:
# None

# %%
tigar=np.linspace(-2*np.pi,2*np.pi,50)
print(tigar)
plt.plot(tigar,np.sin(tigar),color='black')
plt.title("sin(x)")
plt.show()
# Out:
# [-6.28318531 -6.02672876 -5.77027222 -5.51381568 -5.25735913 -5.00090259
#  -4.74444605 -4.48798951 -4.23153296 -3.97507642 -3.71861988 -3.46216333
#  -3.20570679 -2.94925025 -2.6927937  -2.43633716 -2.17988062 -1.92342407
#  -1.66696753 -1.41051099 -1.15405444 -0.8975979  -0.64114136 -0.38468481
#  -0.12822827  0.12822827  0.38468481  0.64114136  0.8975979   1.15405444
#   1.41051099  1.66696753  1.92342407  2.17988062  2.43633716  2.6927937
#   2.94925025  3.20570679  3.46216333  3.71861988  3.97507642  4.23153296
#   4.48798951  4.74444605  5.00090259  5.25735913  5.51381568  5.77027222
#   6.02672876  6.28318531]

# %%
overs=np.arange(5,50,5)
overs_a=np.arange(5,30,5)
runs_i=np.array([25,51,84,131,160,189,220,250,267])
runs_a=np.array([15,41,94,110,151])
wickets=np.array([12,32,96])
plt.subplot(2,1,2)
plt.plot(overs,runs_i,color='blue',label='india')
plt.legend(loc='best')
plt.subplot(2,1,1)
plt.plot(overs_a,runs_a,color='red',label='Aus')
plt.legend(loc='best')
plt.show()

# %%
a=[230,560,780,127,128]
b=[200,160,270,127,400]
years=[1,2,3,4]
profit_a=[(a[i]-a[i-1]) for i in range(1,len(a))]
profit_b=[(b[i]-b[i-1]) for i in range(1,len(b))]
plt.subplot(2,1,2)
plt.plot(years,profit_a,color='hotpink',linewidth='3',label='companyA',marker='>',ms='10',mec='k')
plt.subplot(2,1,1)
plt.plot(years,profit_b,color='black',linestyle='dotted',label='companyB',marker='H')
plt.show()

# %%
a=np.array([25,60,5,10])
labe=["AIML","Python","Pandas","Numpy"]
explo=[0.2,0,0,0]
c=["black","yellow","purple","blue"]
plt.pie(a,labels=labe,colors=c,explode=explo,startangle=180)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
runs=np.array([100,50,91,78,89,25,34,19,9,10])
w=np.array([1,0,2,0,3,7,8,9,7,5])
plt.scatter(runs,w,color='orange')
plt.title('indvsAus_score')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel("/content/Book 5.xlsx")
mean=df['temperature'].mean()
print(mean)
min=df['temperature'].min()
print(min)
max=df['temperature'].max()
print(max)
treshold=32
no_days=df[df['temperature']>treshold].shape[0]
print(no_days)
date=df['date']
temperature=df['temperature']
plt.plot(date,temperature,color='black',linewidth='1',marker='.',)
x=np.array([max,min])
p=df.loc[df['temperature'].idxmax(),'date']
m=df.loc[df['temperature'].idxmin(),'date']
y=np.array([p,m])
plt.scatter(y,x,color='red')
plt.show()
# Out:
# 30.9
# 25
# 36
# 13

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips=sns.load_dataset("tips")
print(tips)

sns.scatterplot(x="total_bill",y="tip",data=tips)
plt.title("scatter plot of total bill vs. tip")
plt.xlabel("total bill ($)")
plt.ylabel("tip($)")
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
iris=sns.load_dataset("iris")
print(iris)

sns.scatterplot(x="sepal_length",y="sepal_width",data=iris)
plt.title("scatter plot of sepal_length vs. sepal_width")
plt.xlabel("sepal_length($)")
plt.ylabel("sepal_width($)")
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris=sns.load_dataset("iris")
print(iris)
correlation_matrix=iris.corr()
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm")
plt.title("correlation heatmap of iris data set")

plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# <ipython-input-32-f27419167600>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=iris.corr()

# %%
titanic=sns.load_dataset("titanic")
print(titanic)
correlation_matrix=titanic.corr()
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm")
plt.title("correlation heatmap of titanic data set")

plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
# <ipython-input-35-526109bac44c>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=titanic.corr()

# %%
tips=sns.load_dataset("tips")
sns.violinplot(x="day",y="total_bill",data=tips)
plt.title("distribution of total_bill vs. day")
plt.xlabel("day($)")
plt.ylabel("total_bill($)")
plt.show()
